# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khushahal07/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# ### One-Row Contract
#
# One row represents a single web page from one client for a specific analysis period. The row contains SEO and content metrics such as impressions, clicks, CTR, average position, and content characteristics that are available before the optimization decision is made.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# ### Lane, Target, and Exclusion
#
# **Lane:** Content Performance
#
# **Target:** Predict which web pages are likely to lose search traffic or experience declining performance so they can be improved before traffic drops.
#
# **One thing to exclude:** Any feature that is created after the decision point or directly reveals the outcome (for example, future traffic changes or labels derived from the target), because it would cause data leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# ### Three Verification Queries
#
# 1. Count the total number of rows in the dataset to confirm the data loaded correctly.
#
# 2. Check for missing values in important fields such as impressions, clicks, CTR, and average position.
#
# 3. Display the first 10 records to verify that the columns and values look correct.

# %% [markdown]
# Three Verification Queries
#
# 1. Count the total number of rows in the dataset to confirm it loaded correctly.
#
# 2. Check for missing values in important fields such as impressions, clicks, CTR, and average position.
#
# 3. Display the first 10 rows to verify that the columns and values look correct.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Verification Query 1: Total rows
print("Total Rows:", len(df))

# Verification Query 2: Missing values
important_cols = ["impressions", "clicks", "ctr", "average_position"]

existing_cols = [c for c in important_cols if c in df.columns]

if existing_cols:
    print("\nMissing Values:")
    print(df[existing_cols].isnull().sum())
else:
    print("\nImportant columns not found.")
    print("Available columns:")
    print(df.columns.tolist())

# Verification Query 3: First 10 rows
print("\nFirst 10 Rows")
display(df.head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_448/1646366998.py in <cell line: 0>()
#       2 # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#       3 # Verification Query 1: Total rows
# ----> 4 print("Total Rows:", len(df))
#       5
#       6 # Verification Query 2: Missing values
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
